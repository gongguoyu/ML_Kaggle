# %%
import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %matplotlib inline

import pandas as pd #数据分析
import numpy as np #科学计算
from pandas import Series,DataFrame

import pickle

# %%
data_train_init = pd.read_csv("./datas/train.csv")
data_test_init = pd.read_csv("./datas/test.csv")

data_train =data_train_init.copy(deep=True)
data_test =data_test_init.copy(deep=True)


data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
def showColums():
    
    print('+'*20)
    
    print(data_train.columns.values.tolist())
    print('-'*20)
    print(data_test.columns.values.tolist())

    print('+'*20)
    
    data_train.info()
    print('-'*20)
    data_test.info()
    
    print('+'*20)
    
showColums()
# Out:
# ++++++++++++++++++++
# ...

# %%
#无意义的标志位删除
def drop(ids):
    ids = list(set(ids))
    
    global data_train
    global data_test
    
    print('Drop:',ids)
    
    
    dealDatas = [data_train,data_test]
    dealDatas_Name = ['data_train','data_test']
    
    for i in range(2):
        print('-----',dealDatas_Name[i],':')
        
        for tempId in ids:
            try:
                dealDatas[i] = dealDatas[i].drop([tempId], axis=1)
            except Exception as e:
                print(e)
                pass
            else:
                print(tempId,)
                
    data_train,data_test = dealDatas

                
dropColumns = []      

#dropColumns.append('Id')
drop(dropColumns)

showColums()
# Out:
# Drop: []
# ----- data_train :
# ----- data_test :
# ++++++++++++++++++++
# ...

# %%
#一些弃用属性的设置

#街道类型
dropColumns.append('Street') #样本比例失衡，丢弃

dropColumns.append('Utilities') #样本比例失衡，丢弃
#巷子类型
dropColumns.append('Alley') #缺失严重，丢弃
dropColumns.append('Condition2') #样本比例失衡，丢弃
dropColumns.append('RoofMatl') #样本比例失衡，丢弃
dropColumns.append('Heating') #样本比例失衡，丢弃
dropColumns.append('LowQualFinSF') #样本比例失衡，丢弃
dropColumns.append('3SsnPorch') #样本比例失衡，丢弃
dropColumns.append('ScreenPorch') #样本比例失衡，丢弃
dropColumns.append('PoolArea') #样本缺失，丢弃
dropColumns.append('PoolQC') #样本缺失，丢弃
dropColumns.append('MiscVal') #样本比例失衡，丢弃
dropColumns.append('MiscFeature') #样本缺失，丢弃
#连接房产的距离
dropColumns.append('LotFrontage') #样本缺失,本版本暂时丢弃  V1

drop(dropColumns)

showColums()
# Out:
# Drop: ['Alley', 'MiscFeature', 'PoolQC', 'Street', 'ScreenPorch', 'Utilities', 'MiscVal', 'LotFrontage', 'LowQualFinSF', 'PoolArea', 'RoofMatl', 'Heating', '3SsnPorch', 'Condition2']
# ----- data_train :
# Alley
# MiscFeature
# PoolQC
# Street
# ScreenPorch
# Utilities
# MiscVal
# LotFrontage
# LowQualFinSF
# PoolArea
# RoofMatl
# Heating
# 3SsnPorch
# Condition2
# ----- data_test :
# Alley
# MiscFeature
# PoolQC
# Street
# ScreenPorch
# Utilities
# MiscVal
# LotFrontage
# LowQualFinSF
# PoolArea
# RoofMatl
# Heating
# 3SsnPorch
# Condition2
# ++++++++++++++++++++
# ...

# %%
fillNanUseMostType = []
#1452，砌体单板类型
#缺失个别值，考虑均值填充（最多的类型）
fillNanUseMostType.append("MasVnrType")
#1459,电力系统
#缺失一个值，考虑均值填充（最多的类型）
fillNanUseMostType.append("Electrical")

#--------以下是只有测试数据中缺少的
#1455,分区总体分类
#缺失个别值，考虑均值填充（最多的类型）
fillNanUseMostType.append("MSZoning")
#1458,外部覆盖物
#缺失一个值，考虑均值填充（最多的类型）
fillNanUseMostType.append("Exterior1st")
#1458,外部覆盖物（超过一种）
#缺失一个值，考虑均值填充（最多的类型）
fillNanUseMostType.append("Exterior2nd")
#1458,厨房质量
#缺失一个值，考虑均值填充（最多的类型）
fillNanUseMostType.append("KitchenQual")
#1457,功能
#缺失2个值，考虑均值填充（最多的类型）
fillNanUseMostType.append("Functional")
#1458,销售类型
#缺失2个值，考虑均值填充（最多的类型）
fillNanUseMostType.append("SaleType")
#--------



#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
fillNanWithNan = []
#1423，地下室高度
#缺失少部分值，为没有地下室，分为一类
fillNanWithNan.append("BsmtQual")
#1423，地下室一般情况
#缺失少部分值，为没有地下室，分为一类
fillNanWithNan.append("BsmtCond")
#1422，一些墙
#缺失少部分，为没有地下室，分为一类
fillNanWithNan.append("BsmtExposure")
#1423，地下室质量
#缺失少部分，为没有地下室，分为一类
fillNanWithNan.append("BsmtFinType1")
#1423，第二个地下室完成质量
#缺失少部分，为没有地下室，分为一类
fillNanWithNan.append("BsmtFinType2")
#770，壁炉质量
#缺失大部分值，为没有壁炉，分为一类
fillNanWithNan.append("FireplaceQu")
#1379，车库方位
#缺失少部分，为没有车库，分为一类
fillNanWithNan.append("GarageType")
#1379，车库装饰
#缺失少部分，为没有车库，分为一类
fillNanWithNan.append("GarageFinish")
#1379，车库质量
#缺失少部分，为没有车库，分为一类
fillNanWithNan.append("GarageQual")
#1379，车库状况
#缺失少部分，为没有车库，分为一类
fillNanWithNan.append("GarageCond")
#1379，围栏质量
#缺失少部分，为没有围栏，分为一类
fillNanWithNan.append("Fence")

#--------以下是只有测试数据中缺少的

#--------

#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
fillNanUseMode = []
#1201,连接房产的距离
#像是随机缺失，考虑近似替代或者模型预测
#fillNanUseMode.append("LotFrontage")  #V1版本暂时放弃这个属性
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
fillNanUseMostTypeMean = []
#1452，砌体单板区域面积
#缺失个别值,分类均值填充
fillNanUseMostTypeMean.append(("MasVnrArea","MasVnrType"))

#--------以下是只有测试数据中缺少的
#1458，类型一完成区域
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("BsmtFinSF1","BsmtFinType1"))
#1458，Type 2 finished square feet
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("BsmtFinSF2","BsmtFinType2"))
#1458，未完工区域
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("BsmtUnfSF","BsmtFinType1"))
#1458，总面积
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("TotalBsmtSF","BsmtFinType1"))
#1457，地下室全浴室
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("BsmtFullBath","BsmtFinType1"))
#1457，地下室半浴室
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("BsmtHalfBath","BsmtFinType1"))
#1458，地下室半浴室
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("GarageCars","GarageType"))
#1458，地下室半浴室
#缺失一个值,分类均值填充
fillNanUseMostTypeMean.append(("GarageArea","GarageFinish"))
#--------
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
fillNanWithOtherFeature = []
#1379，车库建成日期
#缺失少部分，为没有车库，考虑使用建造年份填充
fillNanWithOtherFeature.append(("GarageYrBlt","YearBuilt"))
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++


print(fillNanUseMostType)
print(fillNanWithNan)

print(fillNanUseMostTypeMean)
print(fillNanWithOtherFeature)
print(fillNanUseMode)
# Out:
# ['MasVnrType', 'Electrical', 'MSZoning', 'Exterior1st', 'Exterior2nd', 'KitchenQual', 'Functional', 'SaleType']
# ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'Fence']
# [('MasVnrArea', 'MasVnrType'), ('BsmtFinSF1', 'BsmtFinType1'), ('BsmtFinSF2', 'BsmtFinType2'), ('BsmtUnfSF', 'BsmtFinType1'), ('TotalBsmtSF', 'BsmtFinType1'), ('BsmtFullBath', 'BsmtFinType1'), ('BsmtHalfBath', 'BsmtFinType1'), ('GarageCars', 'GarageType'), ('GarageArea', 'GarageFinish')]
# [('GarageYrBlt', 'YearBuilt')]
# []

# %%
#训练类别均值填充
def dofillNanUseMostType(_fillNanUseMostType):
    print('+'*20)
    print(data_train[_fillNanUseMostType].info())
    
    for name in _fillNanUseMostType:
        #print(data_train[name].value_counts())
        data_train[name][data_train[name].isnull()]=data_train[name].mode().iloc[0]
        data_test[name][data_test[name].isnull()]=data_train[name].mode().iloc[0]
        #print(data_train[name].value_counts())
        #print('-'*10)
        
    
    print(data_train[_fillNanUseMostType].info())
    print('+'*20)

dofillNanUseMostType(fillNanUseMostType)
# Out:
# ++++++++++++++++++++
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 8 columns):
# MasVnrType     1452 non-null object
# Electrical     1459 non-null object
# MSZoning       1460 non-null object
# Exterior1st    1460 non-null object
# Exterior2nd    1460 non-null object
# KitchenQual    1460 non-null object
# Functional     1460 non-null object
# SaleType       1460 non-null object
# dtypes: object(8)
# memory usage: 91.3+ KB
# None
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#未知类型填充
def dofillNanWithNan(_columnNeedDeal):
    print('+'*20)
    print(data_train[_columnNeedDeal].info())
    
    data_train[_columnNeedDeal] = data_train[_columnNeedDeal].fillna('NAN')
    data_test[_columnNeedDeal] = data_test[_columnNeedDeal].fillna('NAN')
    #for name in _columnNeedDeal:
    #    print(data_train[name].value_counts())
    #    print('-'*10)
    
    print(data_train[_columnNeedDeal].info())
    print('+'*20)

dofillNanWithNan(fillNanWithNan)
# Out:
# ++++++++++++++++++++
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
# BsmtQual        1423 non-null object
# BsmtCond        1423 non-null object
# BsmtExposure    1422 non-null object
# BsmtFinType1    1423 non-null object
# BsmtFinType2    1422 non-null object
# FireplaceQu     770 non-null object
# GarageType      1379 non-null object
# GarageFinish    1379 non-null object
# GarageQual      1379 non-null object
# GarageCond      1379 non-null object
# Fence           281 non-null object
# dtypes: object(11)
# memory usage: 125.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
# BsmtQual        1460 non-null object
# BsmtCond        1460 non-null object
# BsmtExposure    1460 non-null object
# BsmtFinType1    1460 non-null object
# BsmtFinType2    1460 non-null object
# FireplaceQu     1460 non-null object
# ...

# %%
#类别均值填充
def dofillNanUseMostTypeMean(_data):
    
    _columnNeedDeal = [x[0] for x in _data]
    _columnContainMessage = [x[1] for x in _data]
    
    print(_columnNeedDeal)
    print(_columnContainMessage)
    
    print('+'*20)
    print(data_train[_columnNeedDeal].info())
    
    for c_deal,c_message in zip(_columnNeedDeal,_columnContainMessage):
        #print(data_train[m][data_train[c].isna()])
        ids = data_train[c_deal].isnull()
        ids_test = data_test[c_deal].isnull()
        
        #print(data_train[c_deal][ids])
        
        gr = data_train.groupby([c_message])[c_deal].mean()
        data_train[c_deal][ids] = data_train[c_message][ids].apply(lambda x:gr[x])
        data_test[c_deal][ids_test] = data_test[c_message][ids_test].apply(lambda x:gr[x])
        
        #print(data_train[c_deal][ids])
        print('-'*10)
    
    print(data_train[_columnNeedDeal].info())
    print('+'*20)

dofillNanUseMostTypeMean(fillNanUseMostTypeMean)
# Out:
# ['MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea']
# ['MasVnrType', 'BsmtFinType1', 'BsmtFinType2', 'BsmtFinType1', 'BsmtFinType1', 'BsmtFinType1', 'BsmtFinType1', 'GarageType', 'GarageFinish']
# ++++++++++++++++++++
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 9 columns):
# MasVnrArea      1452 non-null float64
# BsmtFinSF1      1460 non-null int64
# BsmtFinSF2      1460 non-null int64
# BsmtUnfSF       1460 non-null int64
# TotalBsmtSF     1460 non-null int64
# BsmtFullBath    1460 non-null int64
# BsmtHalfBath    1460 non-null int64
# GarageCars      1460 non-null int64
# GarageArea      1460 non-null int64
# dtypes: float64(1), int64(8)
# memory usage: 102.7 KB
# None
# ----------
# ----------
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# ...

# %%
#使用其他特征填充
def dofillNanWithOtherFeature(_data):
    
    _columnNeedDeal = [x[0] for x in _data]
    _columnContainMessage = [x[1] for x in _data]
    
    print(_columnNeedDeal)
    print(_columnContainMessage)
    
    print('+'*20)
    print(data_train[_columnNeedDeal].info())
    
    for c_deal,c_message in zip(_columnNeedDeal,_columnContainMessage):
        ids = data_train[c_deal].isnull()
        data_train[c_deal][ids]=data_train[c_message][ids]
        
        ids_test = data_test[c_deal].isnull()
        data_test[c_deal][ids_test]=data_test[c_message][ids_test]
    
    print(data_train[_columnNeedDeal].info())
    print('+'*20)

dofillNanWithOtherFeature(fillNanWithOtherFeature)
# Out:
# ['GarageYrBlt']
# ['YearBuilt']
# ++++++++++++++++++++
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 1 columns):
# GarageYrBlt    1379 non-null float64
# dtypes: float64(1)
# memory usage: 11.5 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 1 columns):
# GarageYrBlt    1460 non-null float64
# dtypes: float64(1)
# memory usage: 11.5 KB
# None
# ++++++++++++++++++++
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#模型填充
#暂时无

# %%
data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea LotShape LandContour LotConfig LandSlope  \
# 0   1          60       RL     8450      Reg         Lvl    Inside       Gtl
# 1   2          20       RL     9600      Reg         Lvl       FR2       Gtl
# 2   3          60       RL    11250      IR1         Lvl    Inside       Gtl
# 3   4          70       RL     9550      IR1         Lvl    Corner       Gtl
# 4   5          60       RL    14260      IR1         Lvl       FR2       Gtl
#
#   Neighborhood Condition1    ...    PavedDrive WoodDeckSF  OpenPorchSF  \
# 0      CollgCr       Norm    ...             Y          0           61
# 1      Veenker      Feedr    ...             Y        298            0
# 2      CollgCr       Norm    ...             Y          0           42
# 3      Crawfor       Norm    ...             Y          0           35
# 4      NoRidge       Norm    ...             Y        192           84
#
#    EnclosedPorch  Fence  MoSold YrSold SaleType SaleCondition SalePrice
# ...

# %%
#查看属性差异

tempColumns1 = pd.get_dummies(data_train).columns.tolist()
print(len(tempColumns1))

tempColumns2 = pd.get_dummies(data_test).columns.tolist()
print(len(tempColumns2))


cols = list(data_test.columns.tolist())
AllData = pd.concat((data_train.loc[:, cols],data_test.loc[:, cols]))
tempColumns3 = pd.get_dummies(AllData).columns.tolist()
print(len(tempColumns3))


ret_list = list(set(tempColumns1)^set(tempColumns2))
print(ret_list)

ret_list = list(set(tempColumns1)^set(tempColumns3))
print(ret_list)
# Out:
# 260
# 253
# 259
# ['SalePrice', 'Electrical_Mix', 'HouseStyle_2.5Fin', 'Exterior1st_Stone', 'GarageQual_Ex', 'Exterior1st_ImStucc', 'Exterior2nd_Other']
# ['SalePrice']

# %%
#离散特征处理

''' 版本1，数据可能不一致
data_train = pd.get_dummies(data_train)
data_test = pd.get_dummies(data_test)

cols = list(data_train.columns.tolist())
cols.insert(0, cols.pop(cols.index('Id')))
cols.insert(0, cols.pop(cols.index('SalePrice')))
data_train = data_train.loc[:, cols]
data_test = data_test.loc[:, cols[1:]]


data_train.head()
data_test.head()
'''


SalePrices = data_train['SalePrice']
print(SalePrices.count())

cols = list(data_test.columns.tolist())
AllData = pd.concat((data_train.loc[:, cols],data_test.loc[:, cols]))
AllData = pd.get_dummies(AllData)
print(AllData.info())

cols = list(AllData.columns.tolist())
cols.insert(0, cols.pop(cols.index('Id')))

data_train = AllData.iloc[:SalePrices.count(),:].loc[:, cols]
data_train.insert(0,'SalePrices',SalePrices)
data_test = AllData.iloc[SalePrices.count():,:].loc[:, cols]
# Out:
# 1460
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Columns: 259 entries, Id to SaleCondition_Partial
# dtypes: float64(10), int64(21), uint8(228)
# memory usage: 1.3 MB
# None

# %%
showColums()
# Out:
# ++++++++++++++++++++
# ...

# %%
pickle.dump((data_train,data_test),open("./datas_clean_V1.ggy","wb"))
